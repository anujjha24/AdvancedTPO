# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_06_Operators Part 1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Calculate Annual Salary (1.6.1)

# %%
# Code Needed
monthly_salary = 8000
annual=monthly_salary*12
print(annual)
# Out:
# 96000

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Compare Salaries (1.6.2)

# %%
# Code Needed
avg_salary_analyst = 70000
avg_salary_scientist = 85000
compare=avg_salary_analyst>avg_salary_scientist
print(compare)
# Out:
# False

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Remainder (1.6.3)

# %%
# Code Needed
total_applications = 123
job_openings = 67
print(total_applications%job_openings)
# Out:
# 56

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Increment Job Postings (1.6.4)

# %%
# Code Needed
job_postings = 20
new_posting=1
print(job_postings+new_posting)
# Out:
# 21

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Calculate Average Salary (1.6.5)

# %%
# Code Needed
min_salary = 50000
max_salary = 120000
avg=min_salary+max_salary/2
print(avg)
# Out:
# 110000.0

# %% [markdown]
# ---
